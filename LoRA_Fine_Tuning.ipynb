# %%
# Copies the model weights from google drive into colab
# %cp -r "/content/drive/MyDrive/hf_llama_2_7b" "/content/"

# %%
# Installs required python packages
# !pip install torch accelerate bitsandbytes datasets transformers peft trl scipy astrapy llama_cpp_python
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Collecting accelerate
#   Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 6.3 MB/s eta 0:00:00
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 15.9 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.17.1-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 48.1 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Collecting peft
#   Downloading peft-0.9.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 24.0 MB/s eta 0:00:00
# Collecting trl
#   Downloading trl-0.7.11-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Collecting astrapy
#   Downloading astrapy-0.7.6-py3-none-any.whl (32 kB)
# Collecting llama_cpp_python
#   Downloading llama_cpp_python-0.2.53.tar.gz (36.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 44.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.7.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 12.2 MB/s eta 0:00:00
# Collecting cassio<0.2.0,>=0.1.4 (from astrapy)
#   Downloading cassio-0.1.5-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.3 MB/s eta 0:00:00
# Collecting deprecation<2.2.0,>=2.1.0 (from astrapy)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting httpx[http2]<1,>=0.25.2 (from astrapy)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from astrapy) (0.10.2)
# Collecting diskcache>=5.6.1 (from llama_cpp_python)
#   Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 6.5 MB/s eta 0:00:00
# Collecting cassandra-driver>=3.28.0 (from cassio<0.2.0,>=0.1.4->astrapy)
#   Downloading cassandra_driver-3.29.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 43.8 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (2024.2.2)
# Collecting httpcore==1.* (from httpx[http2]<1,>=0.25.2->astrapy)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (1.3.0)
# Collecting h2<5,>=3 (from httpx[http2]<1,>=0.25.2->astrapy)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx[http2]<1,>=0.25.2->astrapy)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting geomet<0.3,>=0.1 (from cassandra-driver>=3.28.0->cassio<0.2.0,>=0.1.4->astrapy)
#   Downloading geomet-0.2.1.post1-py3-none-any.whl (18 kB)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx[http2]<1,>=0.25.2->astrapy) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geomet<0.3,>=0.1->cassandra-driver>=3.28.0->cassio<0.2.0,>=0.1.4->astrapy) (8.1.7)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Building wheels for collected packages: llama_cpp_python
#   Building wheel for llama_cpp_python (pyproject.toml) ... done
#   Created wheel for llama_cpp_python: filename=llama_cpp_python-0.2.53-cp310-cp310-manylinux_2_35_x86_64.whl size=2759116 sha256=786489b0756d3f8638dd3fc649393b939fa4dd315f6e1ed99ee20ddc77be91c6
#   Stored in directory: /root/.cache/pip/wheels/56/94/10/5407d0fd0a979d77bef8df3d298af7d1d60193b6b759ad217f
# Successfully built llama_cpp_python
# Installing collected packages: shtab, hyperframe, hpack, h11, geomet, docstring-parser, diskcache, dill, deprecation, multiprocess, llama_cpp_python, httpcore, h2, cassandra-driver, bitsandbytes, tyro, httpx, cassio, accelerate, datasets, trl, peft, astrapy
# Successfully installed accelerate-0.27.2 astrapy-0.7.6 bitsandbytes-0.42.0 cassandra-driver-3.29.0 cassio-0.1.5 datasets-2.17.1 deprecation-2.1.0 dill-0.3.8 diskcache-5.6.3 docstring-parser-0.15 geomet-0.2.1.post1 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.4 httpx-0.27.0 hyperframe-6.0.1 llama_cpp_python-0.2.53 multiprocess-0.70.16 peft-0.9.0 shtab-1.7.0 trl-0.7.11 tyro-0.7.3

# %%
# Import required python packages
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer, set_seed, Trainer, TrainingArguments, BitsAndBytesConfig, DataCollatorForLanguageModeling
import bitsandbytes as bnb
from torch import cuda, bfloat16
import transformers
import torch
import torch.nn as nn
from google.colab import userdata
from astrapy.db import AstraDBCollection, AstraDB
from datasets import Dataset

# %%
# Uses GPU for processing if a CUDA device is available
device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# %%
# Set quantization settings
model_id = "hf_llama_2_7b"

bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)
model_config = AutoConfig.from_pretrained(model_id)

# %%
# Loads model weights
model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto'
)

model.eval()
print(f"Model loaded on {device}")

mem = model.get_memory_footprint()
print("Memory footprint: {} ".format(mem))
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Model loaded on cuda:0
# Memory footprint: 3796385792

# %%
# Loads model's associated tokenizer
tokenizer = transformers.AutoTokenizer.from_pretrained(model_id, use_fast=True)

# %%
# Pulls all our instruction data from Astra
token = userdata.get('astra_token')
endpoint = userdata.get('astra_endpoint')

collection_name = "instructions"
astra_db = AstraDB(token=token, api_endpoint=endpoint)
collection = AstraDBCollection(collection_name=collection_name, astra_db=astra_db)

nextPageState = ""
raw_dataset = []
expected_columns = ['instruction', 'input', 'output']

def check_expected_columns(raw_instruction):
  if all(column in raw_instruction for column in expected_columns):
    return True
  else:
    return False

while nextPageState != None:
  if nextPageState == "":
    data = collection.find()
    nextPageState = data['data']['nextPageState']
    raw_instructions = [instruction for instruction in data['data']['documents'] if check_expected_columns(instruction)]
    raw_dataset.extend(raw_instructions)
  else:
    data = collection.find(options={"pageState":nextPageState}, sort = None)
    nextPageState = data['data']['nextPageState']
    raw_instructions = [instruction for instruction in data['data']['documents'] if check_expected_columns(instruction)]
    raw_dataset.extend(raw_instructions)

print(raw_dataset[0])
print(len(raw_dataset))
# Out:
# {'_id': '91c3ee39-1f77-48a1-99b8-306729806529', 'instruction': 'Explain the modifications made to the incremental repair process in Apache Cassandra pre-4.0 versions and in version 4.0 specifically, focusing on how the reliability of the process has been enhanced.', 'input': "In Apache Cassandra versions prior to 4.0, incremental repair faced issues where data could be marked as repaired inconsistently across nodes, leading to overstreaming during subsequent repairs. The process involved anticompaction after streaming data between replicas, but if automatic compaction occurred before anticompaction, data could remain unrepaired. In contrast, Cassandra 4.0 introduces improvements by supervising the repair process with a transaction for consistency. The 'Prepare phase' now includes anticompaction before Merkle trees computation, ensuring that candidate SSTables are marked as pending repair without inconsistencies. Only SSTables in the pending repair pool participate in tree computations and streaming, preventing issues like overstreaming. After repair completion, all replicas are requested to mark pending SSTables as repaired. If nodes fail during repair, these SSTables are released for future compaction and repair attempts.", 'output': "In Apache Cassandra versions prior to 4.0, incremental repair had reliability issues leading to overstreaming. Version 4.0 addresses this by supervising the repair process with transactions, enhancing consistency. The 'Prepare phase' now includes anticompaction before computation, ensuring SSTables are marked as pending repair to avoid inconsistencies. Only SSTables in the pending repair pool participate in repair operations, preventing data mismatches. This improvement makes incremental repair in Cassandra 4.0 more reliable for production environments.", 'article_id': '8935c38f-db34-43d6-9de4-1d05fb75d487'}
# 3799

# %%
# Turns separated instruction dicts from Astra into a dataset of combined instructions
def create_prompt(record):

  start = "Read the Instruction below and provide an answer."
  question = f"### INSTRUCTION:\n{record['instruction']}\n\n"
  response = f"### Context:\n{record['input']}\n"
  answer = f"### Response:\n {record['output']}\n\n"
  end = "### End"

  parts = [part for part in [start, question, response, answer, end] if part]

  formatted_prompt = "\n\n".join(parts)
  formatted_prompt = formatted_prompt.replace('\\n', '\n')

  record["text"] = formatted_prompt

  return record

p = create_prompt(raw_dataset[0])
print(p["text"])
combined_dataset = list(map(create_prompt, raw_dataset))
print(combined_dataset[1]['text'])

dataset = Dataset.from_list([{"text" : record["text"]} for record in combined_dataset])
print(dataset[2])
# Out:
# Read the Instruction below and provide an answer.
#
# ### INSTRUCTION:
# Explain the modifications made to the incremental repair process in Apache Cassandra pre-4.0 versions and in version 4.0 specifically, focusing on how the reliability of the process has been enhanced.
#
#
#
# ### Context:
# In Apache Cassandra versions prior to 4.0, incremental repair faced issues where data could be marked as repaired inconsistently across nodes, leading to overstreaming during subsequent repairs. The process involved anticompaction after streaming data between replicas, but if automatic compaction occurred before anticompaction, data could remain unrepaired. In contrast, Cassandra 4.0 introduces improvements by supervising the repair process with a transaction for consistency. The 'Prepare phase' now includes anticompaction before Merkle trees computation, ensuring that candidate SSTables are marked as pending repair without inconsistencies. Only SSTables in the pending repair pool participate in tree computations and streaming, preventing issues like overstreaming. After repair completion, all replicas are requested to mark pending SSTables as repaired. If nodes fail during repair, these SSTables are released for future compaction and repair attempts.
#
#
# ### Response:
#  In Apache Cassandra versions prior to 4.0, incremental repair had reliability issues leading to overstreaming. Version 4.0 addresses this by supervising the repair process with transactions, enhancing consistency. The 'Prepare phase' now includes anticompaction before computation, ensuring SSTables are marked as pending repair to avoid inconsistencies. Only SSTables in the pending repair pool participate in repair operations, preventing data mismatches. This improvement makes incremental repair in Cassandra 4.0 more reliable for production environments.
#
#
#
# ### End
# Read the Instruction below and provide an answer.
#
# ### INSTRUCTION:
# Provide Practical Advice: Offer actionable, concrete advice and strategies for using NoSQL technologies effectively, drawing on industry best practices.
#
#
#
# ### Context:
# In this post, the author discusses using Ansible to set up an Apache Cassandra database cluster on AWS EC2 instances. Setting up a cluster manually can be tedious, but using Ansible automates configuration management. The process involves creating an organized directory structure for playbooks and roles, creating EC2 instances, defining a security group, setting up an inventory with node IP addresses, and creating a playbook to configure nodes. The playbook includes tasks like installing JRE, unpacking Cassandra tar, replacing default configurations with custom cassandra.yaml, and starting Cassandra. The cassandra.yaml file contains cluster configurations, seed node IP addresses, and listen/rpc addresses. Key points to remember include using public IP for node hosts, placing Java rpm packages and Cassandra tar in the files directory, and using Java 8 for compatibility.
#
#
# ### Response:
#  When setting up a Cassandra cluster using Ansible, ensure to maintain an organized directory structure for playbooks and roles. Remember to use public IP addresses for node hosts and place Java rpm packages as well as the Cassandra tar file in the files directory. Stick to Java 8 for compatibility, as Cassandra is not supported on higher versions. Following these steps will streamline the installation process and ensure successful deployment of distributed systems like Cassandra.
#
#
#
# ### End
# {'text': "Read the Instruction below and provide an answer.\n\n### INSTRUCTION:\nExplain a feature of Cassandra that differentiates it from traditional relational databases.\n\n\n\n### Context:\nApache Cassandra is a distributed NoSQL database management system known for its high availability and scalability. Unlike traditional relational databases that follow a fixed schema structure, Cassandra offers flexibility through its schema-agnostic nature, allowing for dynamic and efficient handling of unstructured, semi-structured, or structured data. Cassandra's architecture is based on a peer-to-peer distributed system with a masterless design, meaning there is no single point of failure. It uses a decentralized approach where data is distributed across multiple nodes, ensuring fault tolerance and continuous availability even in the presence of node failures. Cassandra also supports linear scalability, enabling seamless horizontal scaling by adding more nodes to the cluster without downtime. These features make Cassandra well-suited for handling large volumes of data with high write and read throughput requirements, popularly used in applications requiring real-time analytics, IoT data processing, recommendation engines, and more.\n\n\n### Response:\n Unlike traditional relational databases with fixed schemas, Cassandra's schema flexibility allows for efficient management of diverse data types, making it ideal for dynamic applications like real-time analytics and IoT processing. Additionally, Cassandra's decentralized, fault-tolerant architecture ensures high availability and scalability by distributing data across multiple nodes, enabling seamless horizontal scaling without downtime. These key features position Cassandra as a robust choice for applications demanding continuous availability and high performance in handling massive amounts of data.\n\n\n\n### End"}

# %%
#max length of the model
def get_max_length(model):
    conf = model.config
    max_length = None
    for length_setting in ["n_positions", "max_position_embeddings", "seq_length"]:
        max_length = getattr(model.config, length_setting, None)
        if max_length:
            print(f"Found max lenth: {max_length}")
            break
    if not max_length:
        max_length = 1024
        print(f"Using default max length: {max_length}")
    return max_length
mx = get_max_length(model)
mx
# Out:
# Found max lenth: 2048
# 2048

# %%
#tokenize dataset
dataset = dataset.map(lambda samples: tokenizer(samples['text']), batched=True)
dataset = dataset.filter(lambda sample: len(sample["input_ids"]) < mx)
seed = 402
set_seed(seed)
dataset = dataset.shuffle(seed=seed)
# Out:
# Map:   0%|          | 0/3799 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/3799 [00:00<?, ? examples/s]

# %%
for param in model.parameters():
  param.requires_grad = False  # freeze the model - train adapters later
  if param.ndim == 1:
    # cast the small parameters (e.g. layernorm) to fp32 for stability
    param.data = param.data.to(torch.float32)

model.gradient_checkpointing_enable()  # reduce number of stored activations
model.enable_input_require_grads()

class CastOutputToFloat(nn.Sequential):
  def forward(self, x): return super().forward(x).to(torch.float32)
model.lm_head = CastOutputToFloat(model.lm_head)

# %%
def find_all_linear_names(model):
    cls = bnb.nn.Linear4bit #if args.bits == 4 else (bnb.nn.Linear8bitLt if args.bits == 8 else torch.nn.Linear)
    lora_module_names = set()
    for name, module in model.named_modules():
        if isinstance(module, cls):
            names = name.split('.')
            lora_module_names.add(names[0] if len(names) == 1 else names[-1])

    if 'lm_head' in lora_module_names:  # needed for 16-bit
        lora_module_names.remove('lm_head')
    return list(lora_module_names)

# %%
modules = find_all_linear_names(model)
print(modules)

#['v_proj', 'up_proj', 'down_proj', 'k_proj', 'o_proj', 'q_proj', 'gate_proj']
# Out:
# ['up_proj', 'gate_proj', 'down_proj', 'v_proj', 'k_proj', 'q_proj', 'o_proj']

# %%
from peft import LoraConfig, get_peft_model

config = LoraConfig(
    r=16,  #attention heads
    lora_alpha=64,  #alpha scaling
    target_modules=modules,  #gonna train all
    lora_dropout=0.1,  # dropout probability for layers
    bias="none",
    task_type="CAUSAL_LM", #for Decoder models like GPT Seq2Seq for Encoder-Decoder models like T5
)
##Get the PEFT Model using the downloaded model and the loRA config
model = get_peft_model(model, config)

# %%
# Print Trainable parameters
trainable_params = 0
all_param = 0
for _, param in model.named_parameters():
    all_param += param.numel()
    if param.requires_grad:
        trainable_params += param.numel()
print(
    f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
)
# Out:
# trainable params: 39976960 || all params: 3540389888 || trainable%: 1.1291682911958425

# %%
tokenizer.pad_token = tokenizer.eos_token
trainer = Trainer(
    model=model,
    train_dataset=dataset,
    args=TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=10,
        max_steps=4000, #20,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir="outputs",
        optim="paged_adamw_8bit",
    ),
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False)
)

model.config.use_cache = False  # re-enable for inference to speed up predictions for similar inputs

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='2776' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2776/4000 2:17:59 < 1:00:53, 0.34 it/s, Epoch 2.92/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.164800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.107800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.104000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.950700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.871200</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.083700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.733300</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.753600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.637100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.683400</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.693400</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.435900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.583100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.538500</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.532500</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.428900</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.489300</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.531900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.586600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.471500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.465900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.361300</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.461700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.577400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.494900</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.280400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.498800</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.538100</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.497700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.153100</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.648800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.531000</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.265800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.262800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.403700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.556000</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.182800</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.487200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.582900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.409900</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.429000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.404100</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.383100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.405700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.576200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.281000</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.276600</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.528000</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.457600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.296700</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.284400</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.183600</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.224900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.439000</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.435500</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.330400</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.231300</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.591500</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.377200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.478100</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.330000</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.355600</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.460500</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.304200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.196700</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.271200</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.262900</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.190900</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.446600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.420400</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.404300</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.288200</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.444700</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.309100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.617300</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.339400</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.529400</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.345300</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.512700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.186700</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.213000</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.481900</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.362500</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.400800</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.454100</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.505500</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.239600</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.477300</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.198200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.247200</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.312100</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.227100</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.325700</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.642000</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.489200</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.318900</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.331300</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.389100</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.313200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.419900</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>1.406500</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.279900</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>1.114200</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.254200</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>1.342700</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.279000</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>1.497900</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.044800</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.399900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.302500</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>1.305200</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.373400</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.228300</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.247400</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>1.463500</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.410100</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1.421000</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.250600</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.341600</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.294500</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.318600</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.482800</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>1.323700</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>1.337000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.181900</td>
#     <
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='4000' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4000/4000 3:19:00, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.164800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.107800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.104000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.950700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.871200</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.083700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.733300</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.753600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.637100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.683400</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.693400</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.435900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.583100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.538500</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.532500</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.428900</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.489300</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.531900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.586600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.471500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.465900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.361300</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.461700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.577400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.494900</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.280400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.498800</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.538100</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.497700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.153100</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.648800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.531000</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.265800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.262800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.403700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.556000</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.182800</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.487200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.582900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.409900</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.429000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.404100</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.383100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.405700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.576200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.281000</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.276600</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.528000</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.457600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.296700</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.284400</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.183600</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.224900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.439000</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.435500</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.330400</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.231300</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.591500</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.377200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.478100</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.330000</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.355600</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.460500</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.304200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.196700</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.271200</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.262900</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.190900</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.446600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.420400</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.404300</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.288200</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.444700</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.309100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.617300</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.339400</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.529400</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.345300</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.512700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.186700</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.213000</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.481900</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.362500</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.400800</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.454100</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.505500</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.239600</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.477300</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.198200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.247200</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.312100</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.227100</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.325700</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.642000</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.489200</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.318900</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.331300</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.389100</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.313200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.419900</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>1.406500</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.279900</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>1.114200</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.254200</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>1.342700</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.279000</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>1.497900</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.044800</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.399900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.302500</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>1.305200</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.373400</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.228300</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.247400</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>1.463500</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.410100</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1.421000</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.250600</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.341600</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.294500</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.318600</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.482800</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>1.323700</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>1.337000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.181900</td>
#     </tr>
#     <tr>
#       <td>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# TrainOutput(global_step=4000, training_loss=0.7045261506270617, metrics={'train_runtime': 11945.387, 'train_samples_per_second': 1.339, 'train_steps_per_second': 0.335, 'total_flos': 2.0266070455180493e+17, 'train_loss': 0.7045261506270617, 'epoch': 4.21})

# %%
# %cp -r "/content/outputs" "/content/drive/MyDrive"

# %%
import datetime
now = str(datetime.datetime.now()).replace(" ","_")
model.save_pretrained(save_directory="outputs/lora_adapter_"+now)

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

peft_model_id = "/content/outputs/lora_adapter2024-02-29_16:56:54.106818"
config = PeftConfig.from_pretrained(peft_model_id)
model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path, return_dict=True, load_in_8bit=True, device_map='auto')
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
trained_model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tst = """Read the Instruction below and provide an answer.

### INSTRUCTION:
In this task, you are given an input list A. You need to find all the elements of the list that are numbers and calculate their sum.

['i', '33', 'h', '849', '77']



### RESPONSE:"""
batch = tokenizer(tst, return_tensors='pt')
with torch.cuda.amp.autocast():
  output_tokens = trained_model.generate(**batch, max_new_tokens=90)

print('\n\n', tokenizer.decode(output_tokens[0], skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-088f65443092> in <cell line: 12>()
#      10 ### RESPONSE:"""
#      11 batch = tokenizer(tst, return_tensors='pt')
# ---> 12 input_ids = input_ids.to('cuda')
#      13 with torch.cuda.amp.autocast():
#      14   output_tokens = trained_model.generate(**batch, max_new_tokens=90)
#
# NameError: name 'input_ids' is not defined
